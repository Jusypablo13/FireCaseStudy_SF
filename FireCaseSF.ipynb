# %% [markdown]
# # Análisis de Incidentes de Incendios en San Francisco
#
# Este notebook realiza un análisis de los incidentes de incendios en San Francisco, procesando el dataset, realizando limpieza de datos, y cargando la información en una base de datos PostgreSQL para facilitar su análisis.
#
# ## Requerimientos Previos
#
# Este análisis requiere:
# - **Docker** para ejecutar PostgreSQL en un contenedor.
# - **PostgreSQL** para almacenar y consultar los datos.
# - **pgAdmin** o **DBeaver** para interactuar con PostgreSQL.
# - **Python** y las librerías `pandas`, `SQLAlchemy`, y `psycopg2` para manipulación de datos y conexión a la base de datos.
#
# ---
#
# ## Paso 1: Importar Librerías Necesarias

# %%
from sqlalchemy import create_engine, text
import pandas as pd

# %% [markdown]
# ## Paso 2: Cargar el Dataset

# %%
df = pd.read_csv('Fire_Incidents_20241027.csv')
df.head()
# Out:
# /var/folders/_w/jhch4qtj4_jblfj6w1qhgrl80000gn/T/ipykernel_10960/1469342684.py:1: DtypeWarning: Columns (10,12,13,20,29,38,45,46,55,58,59) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Fire_Incidents_20241027.csv')
#    Incident Number  Exposure Number         ID                Address  \
# 0         14112053                0  141120530    345 STOCKTON STREET
# 1         14112056                0  141120560  9TH ST/MISSION STREET
# 2         14112065                0  141120650         374 5TH STREET
# 3         14112072                0  141120720            2 MARINA BL
# 4         14112077                0  141120770      899 MARKET STREET
#
#   Incident Date  Call Number              Alarm DtTm            Arrival DtTm  \
# 0    2014/11/12    143163275  2014/11/12 07:41:11 PM  2014/11/12 07:47:10 PM
# 1    2014/11/12    143163325  2014/11/12 07:56:08 PM  2014/11/12 08:00:01 PM
# 2    2014/11/12    143163516  2014/11/12 09:02:31 PM  2014/11/12 09:07:00 PM
# 3    2014/11/12    143163605  2014/11/12 09:29:39 PM  2014/11/12 09:35:14 PM
# 4    2014/11/12    143163637  2014/11/12 09:42:50 PM  2014/11/12 09:45:22 PM
#
#                Close DtTm           City  ...  \
# 0  2014/11/12 08:01:25 PM  San Francisco  ...
# 1  2014/11/12 09:02:34 PM  San Francisco  ...
# 2  2014/11/12 09:12:59 PM  San Francisco  ...
# 3  2014/11/12 09:45:55 PM  San Francisco  ...
# 4  2014/11/12 09:48:43 PM  San Francisco  ...
#
#   Automatic Extinguishing System Present Automatic Extinguishing Sytem Type  \
# 0                                    NaN                                NaN
# 1                                    NaN                                NaN
# 2                                    NaN                                NaN
# 3                                    NaN                                NaN
# 4                                    NaN                                NaN
#
#   Automatic Extinguishing Sytem Perfomance  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Automatic Extinguishing Sytem Failure Reason  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    Number of Sprinkler Heads Operating  Supervisor District  \
# 0                                  NaN                  3.0
# 1                                  NaN                  6.0
# 2                                  NaN                  6.0
# 3                                  NaN                  2.0
# 4                                  NaN                  6.0
#
#             neighborhood_district                          point  \
# 0  Financial District/South Beach   POINT (-122.407196 37.78891)
# 1                 South of Market  POINT (-122.414714 37.776231)
# 2                 South of Market  POINT (-122.402278 37.779279)
# 3                          Marina  POINT (-122.432172 37.805278)
# 4                 South of Market  POINT (-122.407946 37.783991)
#
#                data_as_of          data_loaded_at
# 0  2014/11/12 08:01:25 PM  2024/10/27 02:25:51 AM
# 1  2014/11/12 09:02:34 PM  2024/10/27 02:25:51 AM
# 2  2014/11/12 09:12:59 PM  2024/10/27 02:25:51 AM
# 3  2014/11/12 09:45:55 PM  2024/10/27 02:25:51 AM
# 4  2014/11/12 09:48:43 PM  2024/10/27 02:25:51 AM
#
# [5 rows x 66 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 681610 entries, 0 to 681609
# Data columns (total 66 columns):
#  #   Column                                        Non-Null Count   Dtype
# ---  ------                                        --------------   -----
#  0   Incident Number                               681610 non-null  int64
#  1   Exposure Number                               681610 non-null  int64
#  2   ID                                            681610 non-null  int64
#  3   Address                                       681295 non-null  object
#  4   Incident Date                                 681610 non-null  object
#  5   Call Number                                   681610 non-null  int64
#  6   Alarm DtTm                                    681609 non-null  object
#  7   Arrival DtTm                                  681538 non-null  object
#  8   Close DtTm                                    681595 non-null  object
#  9   City                                          679707 non-null  object
#  10  zipcode                                       681441 non-null  object
#  11  Battalion                                     681610 non-null  object
#  12  Station Area                                  680788 non-null  object
#  13  Box                                           383763 non-null  object
#  14  Suppression Units                             681610 non-null  int64
#  15  Suppression Personnel                         681610 non-null  int64
#  16  EMS Units                                     681610 non-null  int64
#  17  EMS Personnel                                 681610 non-null  int64
#  18  Other Units                                   681610 non-null  int64
#  19  Other Personnel                               681610 non-null  int64
#  20  First Unit On Scene                           329824 non-null  object
#  21  Estimated Property Loss                       134125 non-null  float64
#  22  Estimated Contents Loss                       140712 non-null  float64
#  23  Fire Fatalities                               681610 non-null  int64
#  24  Fire Injuries                                 681610 non-null  int64
#  25  Civilian Fatalities                           681610 non-null  int64
#  26  Civilian Injuries                             681610 non-null  int64
#  27  Number of Alarms                              681610 non-null  int64
#  28  Primary Situation                             681596 non-null  object
#  29  Mutual Aid                                    345524 non-null  object
#  30  Action Taken Primary                          681506 non-null  object
#  31  Action Taken Secondary                        43050 non-null   object
#  32  Action Taken Other                            5669 non-null    object
#  33  Detector Alerted Occupants                    35271 non-null   object
#  34  Property Use                                  678512 non-null  object
#  35  Area of Fire Origin                           35231 non-null   object
#  36  Ignition Cause                                35227 non-null   object
#  37  Ignition Factor Primary                       32924 non-null   object
#  38  Ignition Factor Secondary                     254 non-null     object
#  39  Heat Source                                   35229 non-null   object
#  40  Item First Ignited                            35227 non-null   object
#  41  Human Factors Associated with Ignition        32316 non-null   object
#  42  Structure Type                                9963 non-null    object
#  43  Structure Status                              8913 non-null    object
#  44  Floor of Fire Origin                          9665 non-null    float64
#  45  Fire Spread                                   3142 non-null    object
#  46  No Flame Spread                               13030 non-null   object
#  47  Number of floors with minimum damage          6639 non-null    float64
#  48  Number of floors with significant damage      6631 non-null    float64
#  49  Number of floors with heavy damage            6614 non-null    float64
#  50  Number of floors with extreme damage          6616 non-null    float64
#  51  Detectors Present                             8913 non-null    object
#  52  Detector Type                                 4851 non-null    object
#  53  Detector Operation                            4813 non-null    object
#  54  Detector Effectiveness                        3355 non-null    object
#  55  Detector Failure Reason                       265 non-null     object
#  56  Automatic Extinguishing System Present        8963 non-null    object
#  57  Automatic Extinguishing Sytem Type            1098 non-null    object
#  58  Automatic Extinguishing Sytem Perfomance      1101 non-null    object
#  59  Automatic Extinguishing Sytem Failure Reason  80 non-null      object
#  60  Number of Sprinkler Heads Operating           6967 non-null    float64
#  61  Supervisor District                           671180 non-null  float64
#  62  neighborhood_district                         671379 non-null  object
#  63  point                                         681395 non-null  object
#  64  data_as_of                                    681610 non-null  object
#  65  data_loaded_at                                681610 non-null  object
# dtypes: float64(9), int64(15), object(42)
# memory usage: 343.2+ MB

# %%
df.isnull().sum()
# Out:
# Incident Number              0
# Exposure Number              0
# ID                           0
# Address                    315
# Incident Date                0
#                          ...
# Supervisor District      10430
# neighborhood_district    10231
# point                      215
# data_as_of                   0
# data_loaded_at               0
# Length: 66, dtype: int64

# %% [markdown]
# ## Paso 3: Procesamiento de Datos

# %%
# Convertir columnas de fecha a datetime
date_columns = ['Incident Date', 'Alarm DtTm', 'Arrival DtTm', 'Close DtTm']
for col in date_columns:
    df[col] = pd.to_datetime(df[col], errors='coerce')

# Rellenar valores faltantes en 'City' y asignar el resultado nuevamente
df['City'] = df['City'].fillna('San Francisco')

# Eliminar duplicados
df = df.drop_duplicates()

# Convertir "Incident Date" al formato Año-mes-día
df['Incident Date'] = pd.to_datetime(df['Incident Date'], format='%Y/%m/%d', errors='coerce').dt.strftime('%Y-%m-%d')

# Verificar si la conversión fue exitosa
missing_dates = df['Incident Date'].isna().sum()
print(f"{missing_dates} valores NaT en la columna 'Incident Date' después de la conversión")

# Mostrar ejemplos de las primeras filas para verificar el formato
print(df[['Incident Date']].head(10))
# Out:
# 0 valores NaT en la columna 'Incident Date' después de la conversión
#   Incident Date
# 0    2014-11-12
# 1    2014-11-12
# 2    2014-11-12
# 3    2014-11-12
# 4    2014-11-12
# 5    2014-11-12
# 6    2014-11-12
# 7    2014-11-12
# 8    2014-11-12
# 9    2014-11-12

# %% [markdown]
# ## Paso 4: Configurar la Conexión a PostgreSQL

# %%
# Configuración de la base de datos
db_username = 'postgres'
db_password = 'mysecretpassword'
db_host = ''  # Reemplaza con tu IP correcta
db_port = '5432'
db_name = 'postgres'

# Crear el motor de conexión
engine = create_engine(f'postgresql+psycopg2://{db_username}:{db_password}@{db_host}:{db_port}/{db_name}')

# Ejecutar la consulta para listar las tablas
try:
    with engine.connect() as connection:
        result = connection.execute(text("SELECT table_name FROM information_schema.tables WHERE table_schema='public';"))
        tables = result.fetchall()
        print("Tablas en la base de datos:", tables)
except Exception as e:
    print("Error de conexión:", e)
# Out:
# Tablas en la base de datos: [('fire_incidents',)]

# %% [markdown]
# ## Paso 5: Cargar los datos en PostgreSQL

# %%
# Cargar el DataFrame a PostgreSQL
df.to_sql('fire_incidents', engine, if_exists='replace', index=False)
# Out:
# 490

# %% [markdown]
# ## Paso 6: Verificación de los datos en PostgreSQL

# %%
# Verificar la carga de datos
df_from_sql = pd.read_sql("SELECT * FROM fire_incidents LIMIT 5;", engine)
display(df_from_sql)
# Out:
#    Incident Number  Exposure Number         ID                Address  \
# 0         14112053                0  141120530    345 STOCKTON STREET
# 1         14112056                0  141120560  9TH ST/MISSION STREET
# 2         14112065                0  141120650         374 5TH STREET
# 3         14112072                0  141120720            2 MARINA BL
# 4         14112077                0  141120770      899 MARKET STREET
#
#   Incident Date  Call Number          Alarm DtTm        Arrival DtTm  \
# 0    2014-11-12    143163275 2014-11-12 19:41:11 2014-11-12 19:47:10
# 1    2014-11-12    143163325 2014-11-12 19:56:08 2014-11-12 20:00:01
# 2    2014-11-12    143163516 2014-11-12 21:02:31 2014-11-12 21:07:00
# 3    2014-11-12    143163605 2014-11-12 21:29:39 2014-11-12 21:35:14
# 4    2014-11-12    143163637 2014-11-12 21:42:50 2014-11-12 21:45:22
#
#            Close DtTm           City  ...  \
# 0 2014-11-12 20:01:25  San Francisco  ...
# 1 2014-11-12 21:02:34  San Francisco  ...
# 2 2014-11-12 21:12:59  San Francisco  ...
# 3 2014-11-12 21:45:55  San Francisco  ...
# 4 2014-11-12 21:48:43  San Francisco  ...
#
#   Automatic Extinguishing System Present Automatic Extinguishing Sytem Type  \
# 0                                   None                               None
# 1                                   None                               None
# 2                                   None                               None
# 3                                   None                               None
# 4                                   None                               None
#
#   Automatic Extinguishing Sytem Perfomance  \
# 0                                     None
# 1                                     None
# 2                                     None
# 3                                     None
# 4                                     None
#
#   Automatic Extinguishing Sytem Failure Reason  \
# 0                                         None
# 1                                         None
# 2                                         None
# 3                                         None
# 4                                         None
#
#    Number of Sprinkler Heads Operating  Supervisor District  \
# 0                                 None                  3.0
# 1                                 None                  6.0
# 2                                 None                  6.0
# 3                                 None                  2.0
# 4                                 None                  6.0
#
#             neighborhood_district                          point  \
# 0  Financial District/South Beach   POINT (-122.407196 37.78891)
# 1                 South of Market  POINT (-122.414714 37.776231)
# 2                 South of Market  POINT (-122.402278 37.779279)
# 3                          Marina  POINT (-122.432172 37.805278)
# 4                 South of Market  POINT (-122.407946 37.783991)
#
#                data_as_of          data_loaded_at
# 0  2014/11/12 08:01:25 PM  2024/10/27 02:25:51 AM
# 1  2014/11/12 09:02:34 PM  2024/10/27 02:25:51 AM
# 2  2014/11/12 09:12:59 PM  2024/10/27 02:25:51 AM
# 3  2014/11/12 09:45:55 PM  2024/10/27 02:25:51 AM
# 4  2014/11/12 09:48:43 PM  2024/10/27 02:25:51 AM
#
# [5 rows x 66 columns]
